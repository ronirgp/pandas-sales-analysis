# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\Ronal\OneDrive\Desktop\pandas-sales-analysis\data\sales.csv")

# %%
df.query("quantity > 3")
# Out:
#     order_id        date customer     product     category  quantity  price  \
# 1       1002  2026-01-06      Ana       Mouse  Accessories         5     25
# 3       1004  2026-01-10    Maria    Keyboard  Accessories         4     45
# 6       1007  2026-01-18     John  Headphones  Accessories         6     80
# 8       1009  2026-01-22   Carlos       Mouse  Accessories        10     25
# 11      1012  2026-02-05    Maria    Keyboard  Accessories         8     45
# 13      1014  2026-02-12      Ana  Headphones  Accessories         4     80
# 15      1016  2026-02-18    Maria       Mouse  Accessories         7     25
# 18      1019  2026-02-25     John    Keyboard  Accessories         5     45
#
#    region
# 1   South
# 3    West
# 6    East
# 8   North
# 11   West
# 13  South
# 15   West
# 18   East

# %%
df.iloc[[5]][["product", "price"]]
# Out:
#   product  price
# 5   Phone    600

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   order_id    20 non-null     int64
#  1   date        20 non-null     str
#  2   customer    20 non-null     str
#  3   product     20 non-null     str
#  4   category    20 non-null     str
#  5   quantity    20 non-null     int64
#  6   price       20 non-null     int64
#  7   region      20 non-null     str
#  8   total       20 non-null     int64
#  9   high_price  20 non-null     bool
# dtypes: bool(1), int64(4), str(5)
# memory usage: 1.6 KB

# %%
df['product'].unique()
# Out:
# <StringArray>
# ['Laptop', 'Mouse', 'Monitor', 'Keyboard', 'Phone', 'Headphones', 'Tablet']
# Length: 7, dtype: str

# %%
pd.merge(df1, df2, on="customer")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 pd.merge(df1, df2, on="customer")
#
# NameError: name 'df1' is not defined

# %%
df["date"].dt.day_name()
# Out:
# 0        Monday
# 1       Tuesday
# 2      Thursday
# 3      Saturday
# 4        Monday
# 5      Thursday
# 6        Sunday
# 7       Tuesday
# 8      Thursday
# 9        Sunday
# 10       Monday
# 11     Thursday
# 12       Sunday
# 13     Thursday
# 14       Sunday
# 15    Wednesday
# 16       Friday
# 17       Sunday
# 18    Wednesday
# 19     Saturday
# Name: date, dtype: str

# %%
df["customer"].nunique()
# Out:
# 4

# %%
df["product"].value_counts()
# Out:
# product
# Laptop        4
# Mouse         3
# Monitor       3
# Keyboard      3
# Phone         3
# Headphones    2
# Tablet        2
# Name: count, dtype: int64

# %%
df.groupby("region")["quantity"].sum()
# Out:
# region
# East     17
# North    18
# South    13
# West     23
# Name: quantity, dtype: int64

# %%
df["date"].dt.day
# Out:
# 0      5
# 1      6
# 2      8
# 3     10
# 4     12
# 5     15
# 6     18
# 7     20
# 8     22
# 9     25
# 10     2
# 11     5
# 12     8
# 13    12
# 14    15
# 15    18
# 16    20
# 17    22
# 18    25
# 19    28
# Name: date, dtype: int32

# %%
df["customer"].isna().sum()
# Out:
# np.int64(0)

# %%
df.groupby("category")["quantity"].sum().sort_values(ascending=False)
# Out:
# category
# Accessories    49
# Electronics    22
# Name: quantity, dtype: int64

# %%
df["total"] = df["quantity"] * df["price"]

# %%
df["customer"].isna()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# Name: customer, dtype: bool

# %%
df.rename(columns={"costomer": "costomer_name"})
# Out:
#     order_id        date customer     product     category  quantity  price  \
# 0       1001  2026-01-05   Carlos      Laptop  Electronics         2    850
# 1       1002  2026-01-06      Ana       Mouse  Accessories         5     25
# 2       1003  2026-01-08     John     Monitor  Electronics         3    300
# 3       1004  2026-01-10    Maria    Keyboard  Accessories         4     45
# 4       1005  2026-01-12   Carlos      Laptop  Electronics         1    850
# 5       1006  2026-01-15      Ana       Phone  Electronics         2    600
# 6       1007  2026-01-18     John  Headphones  Accessories         6     80
# 7       1008  2026-01-20    Maria      Tablet  Electronics         2    400
# 8       1009  2026-01-22   Carlos       Mouse  Accessories        10     25
# 9       1010  2026-01-25      Ana     Monitor  Electronics         1    300
# 10      1011  2026-02-02     John      Laptop  Electronics         1    850
# ...

# %%
df["high_price"] = df["price"] > 300

# %%
df.groupby("category")["price"].mean()
# Out:
# category
# Accessories     46.25
# Electronics    575.00
# Name: price, dtype: float64

# %%
df.groupby("region")["order_id"].count()
# Out:
# region
# East     5
# North    5
# South    5
# West     5
# Name: order_id, dtype: int64

# %%
df["quantity"].sum()
# Out:
# np.int64(71)

# %%
df.groupby("region")["quantity"].agg(["sum", "mean"])
# Out:
#         sum  mean
# region
# East     17   3.4
# North    18   3.6
# South    13   2.6
# West     23   4.6

# %%
df[df["category"] == "Electronics"].groupby("region")["quantity"].sum()
# Out:
# region
# East     6
# North    8
# South    4
# West     4
# Name: quantity, dtype: int64

# %%
df.sort_values("quantity", ascending=False)
# Out:
#     order_id        date customer     product     category  quantity  price  \
# 8       1009  2026-01-22   Carlos       Mouse  Accessories        10     25
# 11      1012  2026-02-05    Maria    Keyboard  Accessories         8     45
# 15      1016  2026-02-18    Maria       Mouse  Accessories         7     25
# 6       1007  2026-01-18     John  Headphones  Accessories         6     80
# 18      1019  2026-02-25     John    Keyboard  Accessories         5     45
# 1       1002  2026-01-06      Ana       Mouse  Accessories         5     25
# 3       1004  2026-01-10    Maria    Keyboard  Accessories         4     45
# 13      1014  2026-02-12      Ana  Headphones  Accessories         4     80
# 12      1013  2026-02-08   Carlos       Phone  Electronics         3    600
# 2       1003  2026-01-08     John     Monitor  Electronics         3    300
# 0       1001  2026-01-05   Carlos      Laptop  Electronics         2    850
# ...

# %%
df.loc[0,["customer", "region"]]
# Out:
# customer    Carlos
# region       North
# Name: 0, dtype: str

# %%
df.loc[5,["product", "price"]]
# Out:
# product    Phone
# price        600
# Name: 5, dtype: object

# %%
df[(df["price"] < 80) & (df["region"] == "South")]
# Out:
#    order_id        date customer product     category  quantity  price region
# 1      1002  2026-01-06      Ana   Mouse  Accessories         5     25  South

# %%
df[(df["category"] == "Electronics") | (df["category"] == "Furniture")]
# Out:
#     order_id        date customer  product     category  quantity  price  \
# 0       1001  2026-01-05   Carlos   Laptop  Electronics         2    850
# 2       1003  2026-01-08     John  Monitor  Electronics         3    300
# 4       1005  2026-01-12   Carlos   Laptop  Electronics         1    850
# 5       1006  2026-01-15      Ana    Phone  Electronics         2    600
# 7       1008  2026-01-20    Maria   Tablet  Electronics         2    400
# 9       1010  2026-01-25      Ana  Monitor  Electronics         1    300
# 10      1011  2026-02-02     John   Laptop  Electronics         1    850
# 12      1013  2026-02-08   Carlos    Phone  Electronics         3    600
# 14      1015  2026-02-15     John   Tablet  Electronics         2    400
# 16      1017  2026-02-20   Carlos  Monitor  Electronics         2    300
# 17      1018  2026-02-22      Ana   Laptop  Electronics         1    850
# 19      1020  2026-02-28    Maria    Phone  Electronics         2    600
#
#    region
# ...

# %%
df[df["quantity"].between(2, 5)]
# Out:
#     order_id        date customer     product     category  quantity  price  \
# 0       1001  2026-01-05   Carlos      Laptop  Electronics         2    850
# 1       1002  2026-01-06      Ana       Mouse  Accessories         5     25
# 2       1003  2026-01-08     John     Monitor  Electronics         3    300
# 3       1004  2026-01-10    Maria    Keyboard  Accessories         4     45
# 5       1006  2026-01-15      Ana       Phone  Electronics         2    600
# 7       1008  2026-01-20    Maria      Tablet  Electronics         2    400
# 12      1013  2026-02-08   Carlos       Phone  Electronics         3    600
# 13      1014  2026-02-12      Ana  Headphones  Accessories         4     80
# 14      1015  2026-02-15     John      Tablet  Electronics         2    400
# 16      1017  2026-02-20   Carlos     Monitor  Electronics         2    300
# 18      1019  2026-02-25     John    Keyboard  Accessories         5     45
# ...

# %%
df[df["category"].isin(["Electronics", "Furniture"])]
# Out:
#     order_id        date customer  product     category  quantity  price  \
# 0       1001  2026-01-05   Carlos   Laptop  Electronics         2    850
# 2       1003  2026-01-08     John  Monitor  Electronics         3    300
# 4       1005  2026-01-12   Carlos   Laptop  Electronics         1    850
# 5       1006  2026-01-15      Ana    Phone  Electronics         2    600
# 7       1008  2026-01-20    Maria   Tablet  Electronics         2    400
# 9       1010  2026-01-25      Ana  Monitor  Electronics         1    300
# 10      1011  2026-02-02     John   Laptop  Electronics         1    850
# 12      1013  2026-02-08   Carlos    Phone  Electronics         3    600
# 14      1015  2026-02-15     John   Tablet  Electronics         2    400
# 16      1017  2026-02-20   Carlos  Monitor  Electronics         2    300
# 17      1018  2026-02-22      Ana   Laptop  Electronics         1    850
# 19      1020  2026-02-28    Maria    Phone  Electronics         2    600
#
#    region
# ...

# %%
df[df["category"] != "North"]
# Out:
#     order_id        date customer     product     category  quantity  price  \
# 0       1001  2026-01-05   Carlos      Laptop  Electronics         2    850
# 1       1002  2026-01-06      Ana       Mouse  Accessories         5     25
# 2       1003  2026-01-08     John     Monitor  Electronics         3    300
# 3       1004  2026-01-10    Maria    Keyboard  Accessories         4     45
# 4       1005  2026-01-12   Carlos      Laptop  Electronics         1    850
# 5       1006  2026-01-15      Ana       Phone  Electronics         2    600
# 6       1007  2026-01-18     John  Headphones  Accessories         6     80
# 7       1008  2026-01-20    Maria      Tablet  Electronics         2    400
# 8       1009  2026-01-22   Carlos       Mouse  Accessories        10     25
# 9       1010  2026-01-25      Ana     Monitor  Electronics         1    300
# 10      1011  2026-02-02     John      Laptop  Electronics         1    850
# ...

# %%
df[df["region"] == "South"]
# Out:
#     order_id        date customer     product     category  quantity  price  \
# 1       1002  2026-01-06      Ana       Mouse  Accessories         5     25
# 5       1006  2026-01-15      Ana       Phone  Electronics         2    600
# 9       1010  2026-01-25      Ana     Monitor  Electronics         1    300
# 13      1014  2026-02-12      Ana  Headphones  Accessories         4     80
# 17      1018  2026-02-22      Ana      Laptop  Electronics         1    850
#
#    region
# 1   South
# 5   South
# 9   South
# 13  South
# 17  South

# %%
df[df["price"] < 30]
# Out:
#     order_id        date customer product     category  quantity  price region
# 1       1002  2026-01-06      Ana   Mouse  Accessories         5     25  South
# 8       1009  2026-01-22   Carlos   Mouse  Accessories        10     25  North
# 15      1016  2026-02-18    Maria   Mouse  Accessories         7     25   West

# %%
row, column = df.shape
print('row:', row)
print('column:', column)
# Out:
# row: 20
# column: 8

# %%
df.dtypes
# Out:
# order_id    int64
# date          str
# customer      str
# product       str
# category      str
# quantity    int64
# price       int64
# region        str
# dtype: object

# %%
list(df.columns)
# Out:
# ['order_id',
#  'date',
#  'customer',
#  'product',
#  'category',
#  'quantity',
#  'price',
#  'region']

# %%
df[["order_id", "quantity", "region"]]
# Out:
#     order_id  quantity region
# 0       1001         2  North
# 1       1002         5  South
# 2       1003         3   East
# 3       1004         4   West
# 4       1005         1  North
# 5       1006         2  South
# 6       1007         6   East
# 7       1008         2   West
# 8       1009        10  North
# 9       1010         1  South
# 10      1011         1   East
# 11      1012         8   West
# 12      1013         3  North
# 13      1014         4  South
# 14      1015         2   East
# 15      1016         7   West
# 16      1017         2  North
# 17      1018         1  South
# 18      1019         5   East
# 19      1020         2   West

# %%
df.head()
# Out:
#    order_id        date customer   product     category  quantity  price  \
# 0      1001  2026-01-05   Carlos    Laptop  Electronics         2    850
# 1      1002  2026-01-06      Ana     Mouse  Accessories         5     25
# 2      1003  2026-01-08     John   Monitor  Electronics         3    300
# 3      1004  2026-01-10    Maria  Keyboard  Accessories         4     45
# 4      1005  2026-01-12   Carlos    Laptop  Electronics         1    850
#
#   region
# 0  North
# 1  South
# 2   East
# 3   West
# 4  North
