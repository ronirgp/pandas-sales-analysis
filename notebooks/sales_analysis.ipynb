# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\Ronal\OneDrive\Desktop\pandas-sales-analysis\data\sales.csv")

# %%
row, column = df.shape
print('row:', row)
print('column:', column)
# Out:
# row: 20
# column: 8

# %%
df.dtypes
# Out:
# order_id    int64
# date          str
# customer      str
# product       str
# category      str
# quantity    int64
# price       int64
# region        str
# dtype: object

# %%
list(df.columns)
# Out:
# ['order_id',
#  'date',
#  'customer',
#  'product',
#  'category',
#  'quantity',
#  'price',
#  'region']

# %%
df.dtypes
# Out:
# order_id    int64
# date          str
# customer      str
# product       str
# category      str
# quantity    int64
# price       int64
# region        str
# dtype: object

# %%
df[["order_id", "quantity", "region"]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 df[["order_id", "quantity", "rgion"]]
#
# File c:\Users\Ronal\OneDrive\Desktop\Linear-Regression-Business-Analysis\.venv\Lib\site-packages\pandas\core\frame.py:4384, in DataFrame.__getitem__(self, key)
#    4380                 indexer = [indexer]
#    4381         else:
#    4382             if is_iterator(key):
#    4383                 key = list(key)
# -> 4384             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4385
#    4386         # take() does not accept boolean indexers
#    4387         if getattr(indexer, "dtype", None) == bool:
#
# File c:\Users\Ronal\OneDrive\Desktop\Linear-Regression-Business-Analysis\.venv\Lib\site-packages\pandas\core\indexes\base.py:6302, in Index._get_indexer_strict(self, key, axis_name)
#    6299 else:
#    6300     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6302 self._raise_if_missing(keyarr, indexer, axis_name)
#    6304 keyarr = self.take(indexer)
#    6305 if isinstance(key, Index):
#    6306     # GH 42790 - Preserve name from an Index
#
# File c:\Users\Ronal\OneDrive\Desktop\Linear-Regression-Business-Analysis\.venv\Lib\site-packages\pandas\core\indexes\base.py:6355, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6352     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6354 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6355 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['rgion'] not in index"

# %%
df.head()
# Out:
#    order_id        date customer   product     category  quantity  price  \
# 0      1001  2026-01-05   Carlos    Laptop  Electronics         2    850
# 1      1002  2026-01-06      Ana     Mouse  Accessories         5     25
# 2      1003  2026-01-08     John   Monitor  Electronics         3    300
# 3      1004  2026-01-10    Maria  Keyboard  Accessories         4     45
# 4      1005  2026-01-12   Carlos    Laptop  Electronics         1    850
#
#   region
# 0  North
# 1  South
# 2   East
# 3   West
# 4  North
